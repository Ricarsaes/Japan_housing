# %%
import pandas as pd
import numpy as np
import os
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.colors as mcolors
warnings.filterwarnings('ignore')

from japanmap import picture

# %%
prefecture_code = pd.read_csv("japan_housing_data/prefecture_code.csv")
prefecture_code.head()
# Out:
#    Code JpName    EnName
# 0     1    北海道  Hokkaido
# 1     2    青森県   Aomori
# 2     3    岩手県    Iwate
# 3     4    宮城県   Miyagi
# 4     5    秋田県    Akita

# %%
df = pd.DataFrame()

data_dir = "japan_housing_data/trade_prices"

for f in os.listdir(data_dir):
    df_prefecture = pd.read_csv(os.path.join(data_dir, f), low_memory=False)
    df_prefecture["Code"] = int(f.split(".")[0])
    df = pd.concat([df, df_prefecture])

df.head()
# Out:
#    No                         Type            Region  MunicipalityCode  \
# 0   1  Residential Land(Land Only)  Residential Area             40101
# 1   2  Residential Land(Land Only)  Residential Area             40101
# 2   3  Residential Land(Land Only)  Residential Area             40101
# 3   4  Residential Land(Land Only)  Residential Area             40101
# 4   5  Residential Land(Land Only)  Residential Area             40101
#
#            Prefecture               Municipality DistrictName NearestStation  \
# 0  Fukuoka Prefecture  Moji Ward,Kitakyushu City      Aobadai           Moji
# 1  Fukuoka Prefecture  Moji Ward,Kitakyushu City   Oaza Ikawa        Komorie
# 2  Fukuoka Prefecture  Moji Ward,Kitakyushu City   Oaza Ikawa           Moji
# 3  Fukuoka Prefecture  Moji Ward,Kitakyushu City   Oaza Ikawa           Moji
# 4  Fukuoka Prefecture  Moji Ward,Kitakyushu City   Oaza Ikawa           Moji
#
#   TimeToNearestStation  MinTimeToNearestStation  ...  Breadth  \
# 0         30-60minutes                     30.0  ...      4.0
# 1         30-60minutes                     30.0  ...      4.0
# 2              1H-1H30                     60.0  ...      4.0
# 3              1H-1H30                     60.0  ...     35.0
# 4              1H-1H30                     60.0  ...      NaN
#
#                                         CityPlanning CoverageRatio  \
# 0  Category I Exclusively Low-story Residential Zone          50.0
# 1                          Urbanization Control Area           NaN
# 2                          Urbanization Control Area           NaN
# 3                          Urbanization Control Area          70.0
# 4                          Urbanization Control Area          70.0
#
#    FloorAreaRatio            Period  Year  Quarter Renovation  Remarks  Code
# 0            80.0  4th quarter 2017  2017        4        NaN      NaN    40
# 1             NaN  1st quarter 2018  2018        1        NaN      NaN    40
# 2             NaN  4th quarter 2017  2017        4        NaN      NaN    40
# 3           200.0  4th quarter 2016  2016        4        NaN      NaN    40
# 4           200.0  3rd quarter 2016  2016        3        NaN      NaN    40
#
# [5 rows x 39 columns]

# %%
df = pd.merge(left=df, right=prefecture_code, left_on="Code", right_on="Code", how="left")
df.head()
# Out:
#    No                         Type            Region  MunicipalityCode  \
# 0   1  Residential Land(Land Only)  Residential Area             40101
# 1   2  Residential Land(Land Only)  Residential Area             40101
# 2   3  Residential Land(Land Only)  Residential Area             40101
# 3   4  Residential Land(Land Only)  Residential Area             40101
# 4   5  Residential Land(Land Only)  Residential Area             40101
#
#            Prefecture               Municipality DistrictName NearestStation  \
# 0  Fukuoka Prefecture  Moji Ward,Kitakyushu City      Aobadai           Moji
# 1  Fukuoka Prefecture  Moji Ward,Kitakyushu City   Oaza Ikawa        Komorie
# 2  Fukuoka Prefecture  Moji Ward,Kitakyushu City   Oaza Ikawa           Moji
# 3  Fukuoka Prefecture  Moji Ward,Kitakyushu City   Oaza Ikawa           Moji
# 4  Fukuoka Prefecture  Moji Ward,Kitakyushu City   Oaza Ikawa           Moji
#
#   TimeToNearestStation  MinTimeToNearestStation  ...  CoverageRatio  \
# 0         30-60minutes                     30.0  ...           50.0
# 1         30-60minutes                     30.0  ...            NaN
# 2              1H-1H30                     60.0  ...            NaN
# 3              1H-1H30                     60.0  ...           70.0
# 4              1H-1H30                     60.0  ...           70.0
#
#    FloorAreaRatio            Period  Year  Quarter  Renovation  Remarks Code  \
# 0            80.0  4th quarter 2017  2017        4         NaN      NaN   40
# 1             NaN  1st quarter 2018  2018        1         NaN      NaN   40
# 2             NaN  4th quarter 2017  2017        4         NaN      NaN   40
# 3           200.0  4th quarter 2016  2016        4         NaN      NaN   40
# 4           200.0  3rd quarter 2016  2016        3         NaN      NaN   40
#
#    JpName    EnName
# 0     福岡県  Fukuoka
# 1     福岡県  Fukuoka
# 2     福岡県  Fukuoka
# 3     福岡県  Fukuoka
# 4     福岡県  Fukuoka
#
# [5 rows x 41 columns]

# %%
df.columns
# Out:
# Index(['No', 'Type', 'Region', 'MunicipalityCode', 'Prefecture',
#        'Municipality', 'DistrictName', 'NearestStation',
#        'TimeToNearestStation', 'MinTimeToNearestStation',
#        'MaxTimeToNearestStation', 'TradePrice', 'FloorPlan', 'Area',
#        'AreaIsGreaterFlag', 'UnitPrice', 'PricePerTsubo', 'LandShape',
#        'Frontage', 'FrontageIsGreaterFlag', 'TotalFloorArea',
#        'TotalFloorAreaIsGreaterFlag', 'BuildingYear', 'PrewarBuilding',
#        'Structure', 'Use', 'Purpose', 'Direction', 'Classification', 'Breadth',
#        'CityPlanning', 'CoverageRatio', 'FloorAreaRatio', 'Period', 'Year',
#        'Quarter', 'Renovation', 'Remarks', 'Code', 'JpName', 'EnName'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3906518 entries, 0 to 3906517
# Data columns (total 41 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   No                           int64
#  1   Type                         object
#  2   Region                       object
#  3   MunicipalityCode             int64
#  4   Prefecture                   object
#  5   Municipality                 object
#  6   DistrictName                 object
#  7   NearestStation               object
#  8   TimeToNearestStation         object
#  9   MinTimeToNearestStation      float64
#  10  MaxTimeToNearestStation      float64
#  11  TradePrice                   int64
#  12  FloorPlan                    object
#  13  Area                         int64
#  14  AreaIsGreaterFlag            int64
#  15  UnitPrice                    float64
#  16  PricePerTsubo                float64
#  17  LandShape                    object
#  18  Frontage                     float64
#  19  FrontageIsGreaterFlag        bool
#  20  TotalFloorArea               float64
#  21  TotalFloorAreaIsGreaterFlag  int64
#  22  BuildingYear                 float64
#  23  PrewarBuilding               int64
#  24  Structure                    object
#  25  Use                          object
#  26  Purpose                      object
#  27  Direction                    object
#  28  Classification               object
#  29  Breadth                      float64
#  30  CityPlanning                 object
#  31  CoverageRatio                float64
#  32  FloorAreaRatio               float64
#  33  Period                       object
#  34  Year                         int64
#  35  Quarter                      int64
#  36  Renovation                   object
#  37  Remarks                      object
#  38  Code                         int64
#  39  JpName                       object
#  40  EnName                       object
# dtypes: bool(1), float64(10), int64(10), object(20)
# memory usage: 1.2+ GB

# %%
df.describe().apply(lambda s: s.apply('{0:.1f}'.format))
# Out:
#               No MunicipalityCode MinTimeToNearestStation  \
# count  3906518.0        3906518.0               3315977.0
# mean     78354.1          20467.1                    22.6
# std      80173.6          12175.5                    23.1
# min          1.0           1101.0                     0.0
# 25%      20780.0          12204.0                     9.0
# 50%      48159.0          17210.0                    16.0
# 75%     114733.0          28110.0                    30.0
# max     406575.0          47382.0                   120.0
#
#       MaxTimeToNearestStation     TradePrice       Area AreaIsGreaterFlag  \
# count               3228071.0      3906518.0  3906518.0         3906518.0
# mean                     27.4     27605894.6      467.4               0.0
# std                      27.7    141745961.4      847.7               0.2
# min                       0.0          100.0       10.0               0.0
# 25%                       8.0      5000000.0      100.0               0.0
# 50%                      15.0     14000000.0      185.0               0.0
# 75%                      29.0     29000000.0      370.0               0.0
# max                     120.0  61000000000.0     5000.0               1.0
#
#         UnitPrice PricePerTsubo   Frontage TotalFloorArea  \
# count   1384415.0     1384415.0  2537063.0      1317660.0
# mean      85148.9      281406.5       14.6          175.2
# std      168683.2      557031.6        9.8          256.4
# min           1.0           2.0        0.1           10.0
# 25%       16000.0       55000.0        8.5           95.0
# 50%       40000.0      130000.0       12.0          105.0
# 75%       91000.0      300000.0       17.0          140.0
# max    20000000.0    66000000.0       50.0         2000.0
#
#       TotalFloorAreaIsGreaterFlag BuildingYear PrewarBuilding    Breadth  \
# count                   3906518.0    1869804.0      3906518.0  2685837.0
# mean                          0.0       1995.5            0.0        6.8
# std                           0.1         15.2            0.0        4.6
# min                           0.0       1945.0            0.0        1.0
# 25%                           0.0       1984.0            0.0        4.0
# 50%                           0.0       1996.0            0.0        6.0
# 75%                           0.0       2009.0            0.0        7.0
# max                           1.0       2020.0            1.0       99.9
#
#       CoverageRatio FloorAreaRatio       Year    Quarter       Code
# count     3191877.0      3191877.0  3906518.0  3906518.0  3906518.0
# mean           61.0          209.0     2012.9        2.5       20.3
# std            10.0          107.5        3.7        1.1       12.2
# min            30.0           50.0     2005.0        1.0        1.0
# 25%            60.0          200.0     2010.0        2.0       12.0
# 50%            60.0          200.0     2013.0        3.0       17.0
# 75%            60.0          200.0     2016.0        4.0       28.0
# max            80.0         1300.0     2019.0        4.0       47.0

# %%
df['EnName'] = df['EnName'].apply(lambda x: x.rstrip())

# %%
missing_percentage = (df.isnull().mean() * 100).sort_values(ascending=False)
print("Missing percentage\n")
print(missing_percentage)
# Out:
# Missing percentage
#
# Remarks                        94.064791
# Renovation                     85.578052
# FloorPlan                      84.713497
# Purpose                        69.722960
# TotalFloorArea                 66.270218
# PricePerTsubo                  64.561407
# UnitPrice                      64.561407
# BuildingYear                   52.136301
# Use                            51.709579
# Structure                      51.041490
# Frontage                       35.055643
# Breadth                        31.247290
# Classification                 30.514719
# Direction                      28.901646
# LandShape                      28.862788
# Region                         28.595209
# FloorAreaRatio                 18.293555
# CoverageRatio                  18.293555
# MaxTimeToNearestStation        17.367052
# MinTimeToNearestStation        15.116812
# TimeToNearestStation           15.116812
# NearestStation                 14.483768
# CityPlanning                   13.584118
# DistrictName                    0.211825
# Quarter                         0.000000
# Period                          0.000000
# Code                            0.000000
# JpName                          0.000000
# Year                            0.000000
# No                              0.000000
# PrewarBuilding                  0.000000
# TotalFloorAreaIsGreaterFlag     0.000000
# Type                            0.000000
# FrontageIsGreaterFlag           0.000000
# AreaIsGreaterFlag               0.000000
# Area                            0.000000
# TradePrice                      0.000000
# Municipality                    0.000000
# Prefecture                      0.000000
# MunicipalityCode                0.000000
# EnName                          0.000000
# dtype: float64

# %%
df['MunicipalityCode'] = df['MunicipalityCode'].astype(str)

# %%
categorical_cols = df.select_dtypes(include=['object']).columns
for col in categorical_cols:
    df[col].fillna('unkown', inplace=True)

# %%
df_copy = df.copy()

# %%
tohoku_prefectures = ['Aomori', 'Iwate', 'Miyagi', 'Akita', 'Yamagata', 'Fukushima']
tohoku_df = df_copy[df_copy['EnName'].i

# %%
split_index = int(len(tohoku_df) * 0.85)

tohoku_df = tohoku_df.sort_values(by=['Year', 'Quarter'])

# %%
tohoku_df[["Year", "Quarter"]].head(100050)
# Out:
#          Year  Quarter
# 2795922  2005        3
# 2813388  2005        3
# 2813390  2005        3
# 2833069  2005        3
# 2767755  2005        4
# ...       ...      ...
# 2798713  2011        2
# 2798716  2011        2
# 2798720  2011        2
# 2798722  2011        2
# 2798725  2011        2
#
# [100050 rows x 2 columns]

# %%
train_df = tohoku_df.iloc[:split_index]
test_df = tohoku_df.iloc[split_index:]

# %%
print(test_df[['Year', 'Quarter']].head(100000))
# Out:
#          Year  Quarter
# 3686463  2017        3
# 3686496  2017        3
# 3686541  2017        3
# 3686542  2017        3
# 3686554  2017        3
# ...       ...      ...
# 3707932  2019        3
# 3707960  2019        3
# 3708043  2019        3
# 3708375  2019        3
# 3708413  2019        3
#
# [48116 rows x 2 columns]

# %%
def cap_outliers(series, lower_percentile=0.01, upper_percentile=0.99):
    lower = series.quantile(lower_percentile)
    upper = series.quantile(upper_percentile)
    return np.clip(series, lower, upper)

# %%
tohoku_df.head()
# Out:
#             No                                 Type  \
# 2795922  41007          Residential Land(Land Only)
# 2813388  58473  Residential Land(Land and Building)
# 2813390  58475  Residential Land(Land and Building)
# 2833069  78154          Residential Land(Land Only)
# 2767755  12840          Residential Land(Land Only)
#
#                              Region MunicipalityCode         Prefecture  \
# 2795922  Potential Residential Area             4105  Miyagi Prefecture
# 2813388             Industrial Area             4208  Miyagi Prefecture
# 2813390            Residential Area             4208  Miyagi Prefecture
# 2833069  Potential Residential Area             4401  Miyagi Prefecture
# 2767755            Residential Area             4101  Miyagi Prefecture
#
#                           Municipality DistrictName NearestStation  \
# 2795922         Izumi Ward,Sendai City      Fukuoka      Izumichuo
# 2813388                    Kakuda City       Kakuda   Minamikakuda
# 2813390                    Kakuda City       Kakuda   Minamikakuda
# 2833069  Matsushima Town,Miyagi County      Isozaki    Takagimachi
# 2767755          Aoba Ward,Sendai City  Shimoayashi         Ayashi
#
#         TimeToNearestStation  MinTimeToNearestStation  ...  CoverageRatio  \
# 2795922                  2H-                    120.0  ...            NaN
# 2813388                   21                     21.0  ...           60.0
# 2813390                   20                     20.0  ...           60.0
# 2833069                   14                     14.0  ...           40.0
# 2767755                   19                     19.0  ...           60.0
#
#          FloorAreaRatio            Period  Year  Quarter  Renovation  \
# 2795922             NaN  3rd quarter 2005  2005        3      unkown
# 2813388           200.0  3rd quarter 2005  2005        3      unkown
# 2813390           200.0  3rd quarter 2005  2005        3      unkown
# 2833069            60.0  3rd quarter 2005  2005        3      unkown
# 2767755           100.0  4th quarter 2005  2005        4      unkown
#
#                                   Remarks Code  JpName  EnName
# 2795922                            unkown    4     宮城県  Miyagi
# 2813388                            unkown    4     宮城県  Miyagi
# 2813390  Dealings between related objects    4     宮城県  Miyagi
# 2833069         Dealings of adjacent land    4     宮城県  Miyagi
# 2767755                            unkown    4     宮城県  Miyagi
#
# [5 rows x 41 columns]

# %%
columns_to_cap = ["Area", "TotalFloorArea","FloorAreaRatio"]
for col in columns_to_cap:    
    train_df[col] = cap_outliers(train_df[col])

# %%
missing_numerical = train_df.select_dtypes(include=['float64', 'int64']).isna().sum().sort_values(ascending=False)
missing_percentage = (train_df.select_dtypes(include=['float64', 'int64']).isnull().mean() * 100).sort_values(ascending=False)
print("Missing values in numerical variables:")
print(missing_numerical[missing_numerical > 0])
print("\n")
print(missing_percentage[missing_numerical > 0])
# Out:
# Missing values in numerical variables:
# TotalFloorArea             203449
# BuildingYear               194536
# UnitPrice                  166779
# PricePerTsubo              166779
# Frontage                   109546
# FloorAreaRatio             100426
# CoverageRatio              100426
# Breadth                     99952
# MaxTimeToNearestStation     92802
# MinTimeToNearestStation     81753
# dtype: int64
#
#
# TotalFloorArea             74.618014
# BuildingYear               71.349036
# UnitPrice                  61.168734
# PricePerTsubo              61.168734
# Frontage                   40.177661
# FloorAreaRatio             36.832762
# CoverageRatio              36.832762
# Breadth                    36.658916
# MaxTimeToNearestStation    34.036544
# MinTimeToNearestStation    29.984156
# dtype: float64

# %%
columns_to_drop = ['JpName', 'DistrictName', 'UnitPrice','PricePerTsubo', 'No', 
                   'TimeToNearestStation', 'TotalFloorAreaIsGreaterFlag', 'NearestStation', 
                   'Period', 'Year', 'Municipality', 'EnName', 'Prefecture', 
                   'AreaIsGreaterFlag', 'Quarter', 'FrontageIsGreaterFlag'
                   ]
train_df = train_df.drop(columns= columns_to_drop)
test_df = test_df.drop(columns= columns_to_drop)

# %%
from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')

numerical_columns = train_df.select_dtypes(include=['number']).columns
train_df_mean = train_df.copy()
test_df_mean = test_df.copy()
train_df_mean[numerical_columns] = imp_mean.fit_transform(train_df_mean[numerical_columns])
test_df_mean[numerical_columns] = imp_mean.transform(test_df_mean[numerical_columns])
print(test_df_mean[numerical_columns])
# Out:
#          MinTimeToNearestStation  MaxTimeToNearestStation  TradePrice    Area  \
# 3686463                30.000000                60.000000  38000000.0  2000.0
# 3686496                13.000000                13.000000   3900000.0   270.0
# 3686541                23.000000                23.000000  19000000.0   370.0
# 3686542                13.000000                13.000000  30000000.0   400.0
# 3686554                30.000000                60.000000   4800000.0   400.0
# ...                          ...                      ...         ...     ...
# 3707932                31.767937                38.728182    100000.0   190.0
# 3707960                31.767937                38.728182     72000.0   145.0
# 3708043                30.000000                60.000000   2500000.0   890.0
# 3708375                31.767937                38.728182   7600000.0  5000.0
# 3708413                 9.000000                 9.000000   7000000.0   490.0
#
#           Frontage  TotalFloorArea  BuildingYear  PrewarBuilding    Breadth  \
# 3686463  50.000000      195.351925   1992.771602             0.0   6.000000
# 3686496  13.000000      195.351925   1992.771602             0.0  13.500000
# 3686541  20.000000      150.000000   1992.000000             0.0   6.000000
# 3686542  18.000000      115.000000   2017.000000             0.0   9.000000
# 3686554  19.000000      195.351925   1992.771602             0.0  10.000000
# ...            ...             ...           ...             ...        ...
# 3707932  17.770141      195.351925   1992.771602             0.0   7.316347
# 3707960  17.770141      195.351925   1992.771602             0.0   7.316347
# 3708043  20.000000      115.000000   1994.000000             0.0  20.000000
# 3708375  17.770141      195.351925   1992.771602             0.0   7.316347
# 3708413  31.000000      140.000000   1972.000000             0.0   6.000000
#
#          CoverageRatio  FloorAreaRatio  Code
# 3686463      60.000000      200.000000   6.0
# 3686496      60.000000      200.000000   6.0
# 3686541      50.000000       60.000000   6.0
# 3686542      50.000000       60.000000   6.0
# 3686554      61.150394      193.675709   6.0
# ...                ...             ...   ...
# 3707932      61.150394      193.675709   6.0
# 3707960      61.150394      193.675709   6.0
# 3708043      70.000000      200.000000   6.0
# 3708375      61.150394      193.675709   6.0
# 3708413      60.000000      200.000000   6.0
#
# [48116 rows x 12 columns]

# %%
X_train = train_df_mean.drop(columns=["TradePrice"])
y_train = train_df_mean["TradePrice"]
X_test = test_df_mean.drop(columns=["TradePrice"])
y_test = test_df_mean["TradePrice"]

# %%
print("Training data shape: ", X_train.shape, y_train.shape)
print("Test data shape: ", X_test.shape, y_test.shape)
# Out:
# Training data shape:  (272654, 24) (272654,)
# Test data shape:  (48116, 24) (48116,)

# %%
missing_numerical = X_train.select_dtypes(include=['float64', 'int64']).isna().sum().sort_values(ascending=False)
missing_percentage = (X_train.select_dtypes(include=['float64', 'int64']).isnull().mean() * 100).sort_values(ascending=False)
print("Missing values in numerical variables:")
print(missing_numerical[missing_numerical > 0])
print("\n")
print(missing_percentage[missing_numerical > 0])
# Out:
# Missing values in numerical variables:
# Series([], dtype: int64)
#
#
# Series([], dtype: float64)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import LabelEncoder

categorical_cols = X_train.select_dtypes(include=['object']).columns


label_encoders = {}  
if not categorical_cols.empty:
    for col in categorical_cols:
        le = LabelEncoder()
        X_train[col] = le.fit_transform(X_train[col])
        label_encoders[col] = le  

        test_values = X_test[col].unique()
        train_values = le.classes_

        unseen_labels = set(test_values) - set(train_values)
        le.classes_ = np.append(le.classes_, list(unseen_labels))

        X_test[col] = le.transform(X_test[col])

assert X_train.select_dtypes(include=['object']).empty, "X_train still has non-numeric columns!"
assert X_test.select_dtypes(include=['object']).empty, "X_test still has non-numeric columns!"


rf_model = RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1)
rf_model.fit(X_train, y_train)

y_pred = rf_model.predict(X_test)


# mae_rf = mean_absolute_error(y_test, y_pred)
# mse_rf = mean_squared_error(y_test, y_pred)
# rmse_rf = np.sqrt(mse_rf)
r2_rf = r2_score(y_test, y_pred)

# print("\nRandom Forest Model Performance:")
# print(f"Mean Absolute Error: {mae_rf:.4f}")
# print(f"Mean Squared Error: {mse_rf:.4f}")
# print(f"Root Mean Squared Error: {rmse_rf:.4f}")
print(f"R-squared: {r2_rf:.4f}")

importances = rf_model.feature_importances_
feature_names = X_train.columns
importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances}).sort_values(by='Importance', ascending=False)

print("\nFeature Importances:")
print(importance_df)


plt.figure(figsize=(12, 8))
plt.barh(importance_df['Feature'], importance_df['Importance'], color='skyblue')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importance from Random Forest')
plt.gca().invert_yaxis()
plt.show()
# Out:
# R-squared: 0.2818
#
# Feature Importances:
#                     Feature  Importance
# 9            TotalFloorArea    0.148569
# 17                  Breadth    0.140706
# 10             BuildingYear    0.115346
# 6                      Area    0.070933
# 2          MunicipalityCode    0.065728
# 15                Direction    0.057542
# 18             CityPlanning    0.045081
# 3   MinTimeToNearestStation    0.041546
# 8                  Frontage    0.041030
# 4   MaxTimeToNearestStation    0.040863
# 7                 LandShape    0.037949
# 20           FloorAreaRatio    0.031244
# 1                    Region    0.028876
# 13                      Use    0.026892
# 22                  Remarks    0.025689
# 16           Classification    0.024261
# 14                  Purpose    0.015273
# 12                Structure    0.015015
# 23                     Code    0.014198
# 19            CoverageRatio    0.010177
# 0                      Type    0.003010
# 5                 FloorPlan    0.000034
# 21               Renovation    0.000022
# 11           PrewarBuilding    0.000016

# %% [markdown]
# ## XGBoost

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, root_mean_squared_error
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

categorical_cols = X_train.select_dtypes(include=['object']).columns
numerical_columns = X_train.select_dtypes(include=['number']).columns

preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore', drop='first'), categorical_cols)
    ],
    remainder='passthrough'
)

pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('scaler', StandardScaler(with_mean=False)),
    ('model', XGBRegressor(n_estimators=100, learning_rate=0.1, random_state=42))
])

pipeline.fit(X_train, y_train)

y_pred_xgb = pipeline.predict(X_test)

# mae_rf = mean_absolute_error(y_test, y_pred)
# mse_rf = mean_squared_error(y_test, y_pred)
# rmse_rf = np.sqrt(mse_rf)
r2_rf = r2_score(y_test, y_pred)

# print("\nRandom Forest Model Performance:")
# print(f"Mean Absolute Error: {mae_rf:.4f}")
# print(f"Mean Squared Error: {mse_rf:.4f}")
# print(f"Root Mean Squared Error: {rmse_rf:.4f}")
print(f"R-squared: {r2_rf:.4f}")
# Out:
# R-squared: 0.2818

# %%
top_12_features = importance_df.head(12)['Feature'].tolist()
print("Top 12 Features:", top_12_features)
# Out:
# Top 12 Features: ['TotalFloorArea', 'Breadth', 'BuildingYear', 'Area', 'MunicipalityCode', 'Direction', 'CityPlanning', 'MinTimeToNearestStation', 'Frontage', 'MaxTimeToNearestStation', 'LandShape', 'FloorAreaRatio']

# %%
relevant_features = top_12_features
X_train = X_train[relevant_features]
X_test = X_test[relevant_features]
X_test = X_test[relevant_features]

# %% [markdown]
# ## Stacking Regressor

# %%
from sklearn.ensemble import StackingRegressor, GradientBoostingRegressor
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import root_mean_squared_error
from xgboost import XGBRegressor

print(X_train.shape, y_train.shape)

categorical_cols = X_train.select_dtypes(include=['object']).columns
numerical_columns = X_train.select_dtypes(include=['number']).columns


preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore', drop='first'), categorical_cols)
    ],
    remainder='passthrough'
)

base_models = [
    ('linear', LinearRegression(n_jobs=-1)),          
    ('gb', GradientBoostingRegressor(n_estimators=100, max_depth=3, random_state=42)),
    ('xgboost', XGBRegressor(n_estimators=70, learning_rate=0.1, random_state=42))
]

stacking_model = StackingRegressor(
    estimators=base_models,
    final_estimator=LinearRegression(n_jobs=-1),
    n_jobs=-1,  
    passthrough=False  
)
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('stacking', stacking_model)
])
pipeline.fit(X_train, y_train)

y_pred_ensemble = pipeline.predict(X_test)

# mae_rf = mean_absolute_error(y_test, y_pred)
# mse_rf = mean_squared_error(y_test, y_pred)
# rmse_rf = np.sqrt(mse_rf)
r2_rf = r2_score(y_test, y_pred)

# print("\nRandom Forest Model Performance:")
# print(f"Mean Absolute Error: {mae_rf:.4f}")
# print(f"Mean Squared Error: {mse_rf:.4f}")
# print(f"Root Mean Squared Error: {rmse_rf:.4f}")
print(f"R-squared: {r2_rf:.4f}")
# Out:
# (272654, 12) (272654,)
# R-squared: 0.2818

# %%
from sklearn.ensemble import StackingRegressor, GradientBoostingRegressor
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import root_mean_squared_error
from xgboost import XGBRegressor

print(X_train.shape, y_train.shape)

categorical_cols = X_train.select_dtypes(include=['object']).columns
numerical_columns = X_train.select_dtypes(include=['number']).columns


preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore', drop='first'), categorical_cols)
    ],
    remainder='passthrough'
)

base_models = [
    ('linear', LinearRegression(n_jobs=-1)),          
    ('random_forest', RandomForestRegressor(n_estimators=100, max_depth=10, random_state=42, n_jobs=-1)),
    ('xgboost', XGBRegressor(n_estimators=70, learning_rate=0.1, random_state=42))
]

stacking_model = StackingRegressor(
    estimators=base_models,
    final_estimator=LinearRegression(n_jobs=-1),
    n_jobs=-1,  
    passthrough=False  
)
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('stacking', stacking_model)
])
pipeline.fit(X_train, y_train)

y_pred_ensemble = pipeline.predict(X_test)

# mae_rf = mean_absolute_error(y_test, y_pred)
# mse_rf = mean_squared_error(y_test, y_pred)
# rmse_rf = np.sqrt(mse_rf)
r2_rf = r2_score(y_test, y_pred)

# print("\nRandom Forest Model Performance:")
# print(f"Mean Absolute Error: {mae_rf:.4f}")
# print(f"Mean Squared Error: {mse_rf:.4f}")
# print(f"Root Mean Squared Error: {rmse_rf:.4f}")
print("\nEnsemble Model Performance:")
print(f"R-squared: {r2_rf:.4f}")
# Out:
# (272654, 12) (272654,)
#
# Ensemble Model Performance:
# R-squared: 0.2818
